# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y_t = Trend + Seasonality + Error

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
series = pd.Series([i+np.random.randint(10) for i in range(1,100)]) # i에다가 노이즈를 더함, 노이즈는 섞였지만 상향트랜드임

# %%
result = seasonal_decompose(series, model='additive', freq=1)

# %%
# observed 원본데이터

# %%
result.plot();  # ; 가 없으면 같은 그래프 두개 나옴. 패키지 버그임
# ob 상향트랜드에 노이즈를 더한거
# 디컴포지션했을 때 트랜드도 상향, 시즈널 없고 리즈듀얼도 없음. 트랜드로만 모든게 잡힘

# %%
def plot_decompose(decomposeresult):
    fig, (ax1, ax2, ax3, ax4) = plt.subplots(4,1, figsize=(15,8)) # 4개를 하나로 보임
    decomposeresult.observed.plot(legend=False, ax=ax1)
    ax1.set_ylabel('Observed')
    decomposeresult.trend.plot(legend=False, ax=ax2)
    ax2.set_ylabel('Trend') 
    decomposeresult.seasonal.plot(legend=False, ax=ax3)
    ax3.set_ylabel('Seasonal')
    decomposeresult.resid.plot(legend=False, ax=ax4)
    ax4.set_ylabel('Resid')

# %%
plot_decompose(result)

# %%
y_t = Level * Error * Trend * seasonality
log(y_t) = Level + Error + Trend + seasonality
log를 붙이면 *가 +로 풀림

# %%
series = pd.Series([i**2 for i in range(1,100)])

# %%
series.plot() # linear하지 않고 exponational하게 올라감

# %%
result = seasonal_decompose(series, model='multiplicative', freq=1)

# %%
plot_decompose(result)

# %%
airline = pd.read_csv('airline_passengers.csv', index_col='Month')

# %%
airline.head()
# Out:
#          Thousands of Passengers
# Month
# 1949-01                      112
# 1949-02                      118
# 1949-03                      132
# 1949-04                      129
# 1949-05                      121

# %%
airline.plot() # 월별 패신저 수가 상향 패턴 시즈널리티를 갖고 있음 약간 직선으로 보이면서도 곡선으로 보인은거 같기도 함. 멀티~로 디컴포즈를 해도 무방할듯

# %%
airline.index = pd.to_datetime(airline.index)

# %%
airline.head()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121

# %%
result = \
seasonal_decompose(airline['Thousands of Passengers'], 
                          model='multiplicative')

# %%
plot_decompose(result)

# %%
#트랜드를 제거하고 시즈널을 뺀다음 노이즈에서 패턴을 얻어 모델링하고 다시 프로딕션을 할 때 모델링에 시즈널과 트렌드를 더하여 트랜젝션을 함
